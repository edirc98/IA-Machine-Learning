# %% [markdown]
# # MatPlotLib

# %% [markdown]
# ## Dibujar un gráfico de línea

# %%
# !jt -t monokai

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [5,8,1,2])
plt.ylabel('Números')
plt.show()

# %% [markdown]
# ## Mutiples funciones un un gráfico

# %%
plt.plot([1,2,3,4], [5,8,1,2])
plt.plot([2,3,4,5], [5,8,1,2])
plt.show()

# %% [markdown]
# ## Guardar en un archivo

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [5,8,1,2])
plt.plot([2,3,4,5], [5,8,1,2])
plt.savefig('C:\\Users\Edgar\Documents\mi_grafico.jpg', format='jpg')

# %% [markdown]
# ## Se pueden ajustar los ejes

# %%
axes = plt.axes()
axes.set_xlim([-1, 5])
axes.set_ylim([-1, 10])
plt.plot([1,2,3,4], [5,8,1,2])
plt.plot([2,3,4,5], [5,8,1,2])
plt.show()

# %% [markdown]
# ## Añadir parrilla

# %%
axes = plt.axes()
axes.set_xlim([-1, 5])
axes.set_ylim([-1, 10])
axes.grid()
plt.plot([1,2,3,4], [5,8,1,2])
plt.plot([2,3,4,5], [5,8,1,2])
plt.show()

# %% [markdown]
# ## Cambiar los tipos de línea y su color

# %%
axes = plt.axes()
axes.set_xlim([-1, 5])
axes.set_ylim([-1, 10])
axes.grid()
plt.plot([1,2,3,4], [5,8,1,2], 'bs-.')
plt.plot([2,3,4,5], [5,8,1,2], 'r:')
plt.show()

# %% [markdown]
# ## Poniendo títulos en los ejes y leyendas

# %%
axes = plt.axes()
axes.set_xlim([-1, 5])
axes.set_ylim([-1, 10])
axes.grid()
plt.xlabel('Cantidad')
plt.ylabel('Probabilidad')
plt.plot([1,2,3,4], [5,8,1,2], 'bs-')
plt.plot([2,3,4,5], [5,8,1,2], 'r:')
plt.legend(['Azules', 'Rojos'], loc=2)
plt.show()

# %% [markdown]
# ## Gráfico de torta

# %%
values = [12, 30, 5, 32]
colors = ['r', 'g', 'b', 'c']
explode = [0.1, 0.1, 0.1, 0.1]
labels = ['Rusia', 'Argentina', 'Italia', 'Francia']
plt.pie(values, colors= colors, labels=labels, explode = explode)
plt.title('Cantidad de programadores')
plt.show()

# %% [markdown]
# ## Gráfico de barras

# %%
values = [12, 55, 4, 32, 14]
colors = ['r', 'g', 'b', 'c', 'm']
plt.bar(range(0,5), values, color= colors)
plt.show()

# %% [markdown]
# ## Gráfico de dispersión

# %%
from pylab import randn

X = randn(300)
Y = randn(300)
plt.scatter(X,Y)
plt.show()

# %% [markdown]
# ## Histograma

# %%
incomes = np.random.normal(15000, 5000, 10000)
plt.hist(incomes, 50)
plt.show()
